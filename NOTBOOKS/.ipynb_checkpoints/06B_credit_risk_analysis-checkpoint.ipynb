# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
plt.style.use("ggplot")

# %%
df = pd.read_csv("../DATA/processed/loan_feature_engineered.csv")

# %%
df.shape
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120720 entries, 0 to 120719
# Data columns (total 62 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   120720 non-null  str
#  1   applicant_id              120720 non-null  str
#  2   customer_name             120720 non-null  str
#  3   gender                    120720 non-null  str
#  4   date_of_birth             120720 non-null  str
#  5   age                       120720 non-null  int64
#  6   marital_status            120720 non-null  str
#  7   education                 120720 non-null  str
#  8   occupation                120720 non-null  str
#  9   employment_type           120720 non-null  str
#  10  employer_name             120720 non-null  str
#  11  years_with_employer       120720 non-null  float64
#  12  annual_income             120720 non-null  float64
#  13  monthly_income            120720 non-null  float64
#  14  city                      120720 non-null  str
#  15  state                     120720 non-null  str
#  16  pincode                   120720 non-null  int64
#  17  branch_id                 120720 non-null  str
#  18  branch_name               120720 non-null  str
#  19  region                    120720 non-null  str
#  20  loan_product              120720 non-null  str
#  21  loan_purpose              120720 non-null  str
#  22  loan_amount               120720 non-null  float64
#  23  sanctioned_amount         120720 non-null  float64
#  24  disbursed_amount          120720 non-null  float64
#  25  interest_rate             120720 non-null  float64
#  26  tenure_months             120720 non-null  int64
#  27  emi_amount                120720 non-null  float64
#  28  processing_fee            120720 non-null  float64
#  29  credit_score              120720 non-null  float64
#  30  debt_to_income_ratio      120720 non-null  float64
#  31  existing_loans_count      120720 non-null  int64
#  32  existing_emi_obligations  120720 non-null  float64
#  33  collateral_type           48407 non-null   str
#  34  collateral_value          120720 non-null  float64
#  35  co_applicant_flag         120720 non-null  str
#  36  application_date          120720 non-null  str
#  37  approval_date             120720 non-null  str
#  38  disbursal_date            120720 non-null  str
#  39  loan_status               120720 non-null  str
#  40  default_flag              120720 non-null  int64
#  41  days_past_due             120720 non-null  float64
#  42  npa_flag                  120720 non-null  str
#  43  recovery_amount           120720 non-null  float64
#  44  loan_officer_id           120720 non-null  str
#  45  loan_officer_name         120720 non-null  str
#  46  payment_history_score     120720 non-null  float64
#  47  bounce_count              120720 non-null  int64
#  48  risk_category             120720 non-null  str
#  49  customer_segment          120720 non-null  str
#  50  is_fraud_suspected        120720 non-null  str
#  51  kyc_verified              120720 non-null  str
#  52  channel                   120720 non-null  str
#  53  age_group                 120720 non-null  str
#  54  income_category           120720 non-null  str
#  55  credit_score_category     120718 non-null  str
#  56  loan_amount_category      120720 non-null  str
#  57  emi_to_income_ratio       120720 non-null  float64
#  58  loan_utilization          120720 non-null  float64
#  59  approval_percentage       120720 non-null  float64
#  60  high_risk_flag            120720 non-null  int64
#  61  loan_count_category       120720 non-null  str
# dtypes: float64(19), int64(7), str(36)
# memory usage: 57.1 MB

# %%
#Default Rate by State
state_default = (
    df.groupby("state")
      .agg(
          Total_Loans=("loan_id", "count"),
          Default_Loans=("default_flag", "sum"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

state_default["Default_Rate"] = (
    state_default["Default_Rate"] * 100
).round(2)

state_default = state_default.sort_values(
    by="Default_Rate",
    ascending=False
)

state_default.head(10)
# Out:
#              state  Total_Loans  Default_Loans  Default_Rate
# 1            Bihar         4821            485         10.06
# 14     West Bengal         9668            667          6.90
# 13   Uttar Pradesh         9669            599          6.20
# 2            Delhi         9680            572          5.91
# 10       Rajasthan         9664            509          5.27
# 9           Punjab         9735            499          5.13
# 12       Telangana         9647            492          5.10
# 8      Maharashtra         9478            467          4.93
# 0   Andhra Pradesh         4832            237          4.90
# 5        Karnataka         9639            461          4.78

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=state_default.head(10),
    x="state",
    y="Default_Rate"
)

plt.xticks(rotation=45)
plt.title("Top 10 States by Default Rate")
plt.ylabel("Default Rate (%)")
plt.xlabel("State")

plt.show()

# %%
#Default Rate by Region
region_default = (
    df.groupby("region")
      .agg(
          Total_Loans=("loan_id", "count"),
          Default_Loans=("default_flag", "sum"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

region_default["Default_Rate"] = (
    region_default["Default_Rate"] * 100
).round(2)

region_default.sort_values(
    by="Default_Rate",
    ascending=False
)
# Out:
#     region  Total_Loans  Default_Loans  Default_Rate
# 1     East        14489           1152          7.95
# 2    North        43612           2395          5.49
# 3    South        38618           1853          4.80
# 4     West        19193            840          4.38
# 0  Central         4808            181          3.76

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=region_default,
    x="region",
    y="Default_Rate"
)

plt.title("Default Rate by Region")
plt.ylabel("Default Rate (%)")
plt.show()

# %%
#DEFAULT RATE BY BRANCH
branch_default = (
    df.groupby("branch_name")
      .agg(
          Total_Loans=("loan_id", "count"),
          Default_Loans=("default_flag", "sum"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

branch_default["Default_Rate"] = (
    branch_default["Default_Rate"] * 100
).round(2)

branch_default = branch_default.sort_values(
    by="Default_Rate",
    ascending=False
)

branch_default.head(10)
# Out:
#                   branch_name  Total_Loans  Default_Loans  Default_Rate
# 13          Patna City Branch         4821            485         10.06
# 3          Howrah City Branch         4837            392          8.10
# 8         Lucknow City Branch         4748            376          7.92
# 14         Rohini City Branch         9680            572          5.91
# 7         Kolkata City Branch         4831            275          5.69
# 4       Hyderabad Main Branch         4765            255          5.35
# 6         Jodhpur City Branch         9664            509          5.27
# 9        Ludhiana Main Branch         9735            499          5.13
# 12         Nashik City Branch         4719            241          5.11
# 17  Visakhapatnam Main Branch         4832            237          4.90

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=branch_default.head(10),
    x="branch_name",
    y="Default_Rate"
)

plt.xticks(rotation=45)
plt.title("Top 10 Branches by Default Rate")
plt.ylabel("Default Rate (%)")

plt.show()

# %%
#Credit Score vs Default

# %%
credit_analysis = (
    df.groupby("credit_score_category")
      .agg(
          Customers=("loan_id", "count"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

credit_analysis["Default_Rate"] = (
    credit_analysis["Default_Rate"] * 100
).round(2)

credit_analysis
# Out:
#   credit_score_category  Customers  Default_Rate
# 0             Excellent      10464          2.03
# 1                  Fair      37509          6.21
# 2                  Good      38846          4.49
# 3                  Poor      15462         10.18
# 4             Very Good      18437          3.04

# %%
credit_analysis = (
    df.groupby("credit_score_category")
      .agg(
          Customers=("loan_id", "count"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

credit_analysis["Default_Rate"] = (
    credit_analysis["Default_Rate"] * 100
).round(2)

credit_analysis
# Out:
#   credit_score_category  Customers  Default_Rate
# 0             Excellent      10464          2.03
# 1                  Fair      37509          6.21
# 2                  Good      38846          4.49
# 3                  Poor      15462         10.18
# 4             Very Good      18437          3.04

# %%
#Debt-to-Income Ratio Analysis

# %%
dti_analysis = (
    df.groupby("high_risk_flag")
      .agg(
          Customers=("loan_id", "count"),
          Average_DTI=("debt_to_income_ratio", "mean"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

dti_analysis["Default_Rate"] = (
    dti_analysis["Default_Rate"] * 100
).round(2)

dti_analysis
# Out:
#    high_risk_flag  Customers  Average_DTI  Default_Rate
# 0               0     120720     0.505958          5.32

# %%
plt.figure(figsize=(6,4))

sns.barplot(
    data=dti_analysis,
    x="high_risk_flag",
    y="Default_Rate"
)

plt.xticks([0, 1], ["Low Risk", "High Risk"])

plt.title("High Risk Flag vs Default Rate")
plt.ylabel("Default Rate (%)")

plt.show()

# %%
#Default Rate by Income Category

# %%
income_default = (
    df.groupby("income_category")
      .agg(
          Total_Loans=("loan_id", "count"),
          Default_Loans=("default_flag", "sum"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

income_default["Default_Rate"] = (
    income_default["Default_Rate"] * 100
).round(2)

income_default
# Out:
#   income_category  Total_Loans  Default_Loans  Default_Rate
# 0            High        27140           1164          4.29
# 1             Low        30238           2551          8.44
# 2          Medium        33170           1748          5.27
# 3       Very High        30172            958          3.18

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=income_default,
    x="income_category",
    y="Default_Rate"
)

plt.title("Default Rate by Income Category")
plt.ylabel("Default Rate (%)")
plt.show()

# %%
existing_loan_analysis = (
    df.groupby("loan_count_category")
      .agg(
          Customers=("loan_id", "count"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

existing_loan_analysis["Default_Rate"] = (
    existing_loan_analysis["Default_Rate"] * 100
).round(2)

existing_loan_analysis
# Out:
#   loan_count_category  Customers  Default_Rate
# 0                 1-2      68917          5.70
# 1                 3-5      11837          8.83
# 2                  5+         97         11.34
# 3             No Loan      39869          3.60

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=existing_loan_analysis,
    x="loan_count_category",
    y="Default_Rate"
)

plt.title("Existing Loans vs Default Rate")
plt.ylabel("Default Rate (%)")
plt.show()

# %%
employment_default = (
    df.groupby("employment_type")
      .agg(
          Customers=("loan_id", "count"),
          Default_Rate=("default_flag", "mean"),
          Average_Credit_Score=("credit_score", "mean")
      )
      .reset_index()
)

employment_default["Default_Rate"] = (
    employment_default["Default_Rate"] * 100
).round(2)

employment_default
# Out:
#               employment_type  Customers  Default_Rate  Average_Credit_Score
# 0              Business Owner      11948          4.83            680.711751
# 1                    Salaried      66505          4.83            679.716758
# 2      Self-Employed Business      24208          6.42            679.927669
# 3  Self-Employed Professional      18059          5.99            679.560939

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=employment_default,
    x="employment_type",
    y="Default_Rate"
)

plt.title("Employment Type vs Default Rate")
plt.ylabel("Default Rate (%)")
plt.show()

# %%
product_default = (
    df.groupby("loan_product")
      .agg(
          Customers=("loan_id", "count"),
          Default_Rate=("default_flag", "mean")
      )
      .reset_index()
)

product_default["Default_Rate"] = (
    product_default["Default_Rate"] * 100
).round(2)

product_default = product_default.sort_values(
    by="Default_Rate",
    ascending=False
)

product_default
# Out:
#     loan_product  Customers  Default_Rate
# 3  Personal Loan      48207          5.95
# 2      Gold Loan      18138          5.58
# 1  Business Loan      24106          5.15
# 0      Auto Loan      30269          4.29

# %%
plt.figure(figsize=(10,5))

sns.barplot(
    data=product_default,
    x="loan_product",
    y="Default_Rate"
)

plt.xticks(rotation=45)
plt.title("Loan Product vs Default Rate")
plt.ylabel("Default Rate (%)")
plt.show()

# %%
#orrelation Analysis

corr = df.select_dtypes(include=["int64", "float64"]).corr()

corr
# Out:
#                                age  years_with_employer  annual_income  \
# age                       1.000000             0.001684      -0.004337
# years_with_employer       0.001684             1.000000      -0.004228
# annual_income            -0.004337            -0.004228       1.000000
# monthly_income           -0.003866            -0.002484       0.332604
# pincode                   0.000756             0.000545      -0.001628
# loan_amount              -0.000235            -0.000222       0.634230
# sanctioned_amount        -0.000774            -0.001701       0.785801
# disbursed_amount         -0.000745            -0.001712       0.785730
# interest_rate            -0.002510             0.002189      -0.000188
# tenure_months            -0.001765             0.006298      -0.000213
# emi_amount                0.000424            -0.002177       0.579308
# processing_fee           -0.001692            -0.001876       0.678135
# credit_score             -0.000067             0.002599       0.003519
# debt_to_income_ratio      0.003049             0.001888      -0.223793
# existing_loans_count     -0.002141             0.002278       0.003828
# existing_emi_obligations -0.002192             0.002608       0.004634
# collateral_value          0.004532             0.001803       0.326700
# default_flag              0.002762            -0.001272      -0.073262
# days_past_due             0.003362            -0.001684      -0.065565
# recovery_amount           0.000712             0.000150       0.034588
# payment_history_score    -0.003897             0.001992       0.128335
# bounce_count              0.003264            -0.000204      -0.063416
# emi_to_income_ratio       0.004794            -0.002393      -0.000482
# loan_utilization          0.002018            -0.000984      -0.004073
# approval_percentage      -0.003057            -0.001987      -0.003521
# high_risk_flag                 NaN                  NaN            NaN
#
#                           monthly_income   pincode  loan_amount  \
# age                            -0.003866  0.000756    -0.000235
# years_with_employer            -0.002484  0.000545    -0.000222
# annual_income                   0.332604 -0.001628     0.634230
# monthly_income                  1.000000 -0.000938     0.224061
# pincode                        -0.000938  1.000000    -0.003011
# loan_amount                     0.224061 -0.003011     1.000000
# sanctioned_amount               0.278742 -0.002289     0.804555
# disbursed_amount                0.278746 -0.002307     0.804518
# interest_rate                   0.003174 -0.001206    -0.000783
# tenure_months                   0.001163 -0.001855    -0.000093
# emi_amount                      0.203442 -0.001926     0.595347
# processing_fee                  0.243011 -0.000595     0.694053
# credit_score                   -0.003028  0.006381     0.005854
# debt_to_income_ratio           -0.077968 -0.003502     0.010708
# existing_loans_count           -0.000230 -0.004303     0.004041
# existing_emi_obligations        0.000492 -0.002328     0.005726
# collateral_value                0.119993  0.000549     0.336292
# default_flag                   -0.023621  0.002267    -0.035574
# days_past_due                  -0.020549  0.000811    -0.032510
# recovery_amount                 0.013944 -0.000986     0.062012
# payment_history_score           0.043210  0.000054     0.033027
# bounce_count                   -0.020279  0.003293    -0.030895
# emi_to_income_ratio            -0.048951 -0.002324     0.219568
# loan_utilization               -0.001256 -0.001478    -0.000804
# approval_percentage            -0.000844  0.001237    -0.346360
# high_risk_flag                       NaN       NaN          NaN
#
#                           sanctioned_amount  disbursed_amount  interest_rate  \
# age                               -0.000774         -0.000745      -0.002510
# years_with_employer               -0.001701         -0.001712       0.002189
# annual_income                      0.785801          0.785730      -0.000188
# monthly_income                     0.278742          0.278746       0.003174
# pincode                           -0.002289         -0.002307      -0.001206
# loan_amount                        0.804555          0.804518      -0.000783
# sanctioned_amount                  1.000000          0.999891       0.000419
# disbursed_amount                   0.999891          1.000000       0.000565
# interest_rate                      0.000419          0.000565       1.000000
# tenure_months                      0.000653          0.000702       0.049004
# emi_amount                         0.737061          0.737084      -0.054612
# processing_fee                     0.862406          0.862264      -0.000942
# credit_score                       0.003214          0.003247       0.002447
# debt_to_income_ratio               0.013788          0.013859      -0.045785
# existing_loans_count               0.002993          0.002976       0.001134
# existing_emi_obligations           0.004130          0.004123      -0.000043
# collateral_value                   0.417355          0.417268      -0.558014
# default_flag                      -0.041135         -0.041194       0.018047
# days_past_due                     -0.037691         -0.037756       0.016678
# recovery_amount                    0.081699          0.081609       0.014140
# payment_history_score              0.038536          0.038556       0.004874
# bounce_count                      -0.036706         -0.036744       0.016194
# emi_to_income_ratio                0.274596          0.274712      -0.077625
# loan_utilization                  -0.002839          0.008980       0.011502
# approval_percentage                0.023866          0.023831      -0.002465
# high_risk_flag                          NaN               NaN            NaN
#
#                           tenure_months  emi_amount  processing_fee  \
# age                           -0.001765    0.000424       -0.001692
# years_with_employer            0.006298   -0.002177       -0.001876
# annual_income                 -0.000213    0.579308        0.678135
# monthly_income                 0.001163    0.203442        0.243011
# pincode                       -0.001855   -0.001926       -0.000595
# loan_amount                   -0.000093    0.595347        0.694053
# sanctioned_amount              0.000653    0.737061        0.862406
# disbursed_amount               0.000702    0.737084        0.862264
# interest_rate                  0.049004   -0.054612       -0.000942
# tenure_months                  1.000000   -0.440783        0.001441
# emi_amount                    -0.440783    1.000000        0.633779
# processing_fee                 0.001441    0.633779        1.000000
# credit_score                   0.001712    0.000634        0.003930
# debt_to_income_ratio          -0.455423    0.343326        0.011915
# existing_loans_count           0.000530    0.001262        0.003389
# existing_emi_obligations      -0.000172    0.001516        0.004539
# collateral_value              -0.000744    0.361731        0.362040
# default_flag                  -0.042654   -0.000491       -0.035512
# days_past_due                 -0.038900   -0.001578       -0.032716
# recovery_amount               -0.036016    0.095932        0.068141
# payment_history_score          0.166725   -0.100818        0.033181
# bounce_count                  -0.035220   -0.003413       -0.032106
# emi_to_income_ratio           -0.637803    0.688895        0.236455
# loan_utilization               0.002388    0.002520       -0.005085
# approval_percentage           -0.000906    0.016879        0.020014
# high_risk_flag                      NaN         NaN             NaN
#
#                           credit_score  debt_to_income_ratio  \
# age                          -0.000067              0.003049
# years_with_employer           0.002599              0.001888
# annual_income                 0.003519             -0.223793
# monthly_income               -0.003028             -0.077968
# pincode                       0.006381             -0.003502
# loan_amount                   0.005854              0.010708
# sanctioned_amount             0.003214              0.013788
# disbursed_amount              0.003247              0.013859
# interest_rate                 0.002447             -0.045785
# tenure_months                 0.001712             -0.455423
# emi_amount                    0.000634              0.343326
# processing_fee                0.003930              0.011915
# credit_score                  1.000000             -0.005115
# debt_to_income_ratio         -0.005115              1.000000
# existing_loans_count         -0.004743              0.502604
# existing_emi_obligations     -0.006074              0.587793
# collateral_value             -0.000828              0.037291
# default_flag                 -0.107473              0.156120
# days_past_due                -0.093219              0.137240
# recovery_amount              -0.078342              0.093019
# payment_history_score         0.082979             -0.433295
# bounce_count                 -0.089160              0.128573
# emi_to_income_ratio          -0.000266              0.677927
# loan_utilization              0.001537              0.003828
# approval_percentage          -0.005812              0.022047
# high_risk_flag                     NaN                   NaN
#
#                           existing_loans_count  existing_emi_obligations  \
# age                                  -0.002141                 -0.002192
# years_with_employer                   0.002278                  0.002608
# annual_income                         0.003828                  0.004634
# monthly_income                       -0.000230                  0.000492
# pincode                              -0.004303                 -0.002328
# loan_amount                           0.004041                  0.005726
# sanctioned_amount                     0.002993                  0.004130
# disbursed_amount                      0.002976                  0.004123
# interest_rate                         0.001134                 -0.000043
# tenure_months                         0.000530                 -0.000172
# emi_amount                            0.001262                  0.001516
# processing_fee                        0.003389                  0.004539
# credit_score                         -0.004743                 -0.006074
# debt_to_income_ratio                  0.502604                  0.587793
# existing_loans_count                  1.000000                  0.841817
# existing_emi_obligations              0.841817                  1.000000
# collateral_value                     -0.001986                 -0.001553
# default_flag                          0.075455                  0.091145
# days_past_due                         0.068067                  0.080617
# recovery_amount                       0.043260                  0.050471
# payment_history_score                -0.210739                 -0.252647
# bounce_count                          0.062298                  0.075330
# emi_to_income_ratio                  -0.001808                 -0.000470
# loan_utilization                     -0.003785                 -0.002686
# approval_percentage                  -0.001401                 -0.001217
# high_risk_flag                             NaN                       NaN
#
#                           collateral_value  default_flag  days_past_due  \
# age                               0.004532      0.002762       0.003362
# years_with_employer               0.001803     -0.001272      -0.001684
# annual_income                     0.326700     -0.073262      -0.065565
# monthly_income                    0.119993     -0.023621      -0.020549
# pincode                           0.000549      0.002267       0.000811
# loan_amount                       0.336292     -0.035574      -0.032510
# sanctioned_amount                 0.417355     -0.041135      -0.037691
# disbursed_amount                  0.417268     -0.041194      -0.037756
# interest_rate                    -0.558014      0.018047       0.016678
# tenure_months                    -0.000744     -0.042654      -0.038900
# emi_amount                        0.361731     -0.000491      -0.001578
# processing_fee                    0.362040     -0.035512      -0.032716
# credit_score                     -0.000828     -0.107473      -0.093219
# debt_to_income_ratio              0.037291      0.156120       0.137240
# existing_loans_count             -0.001986      0.075455       0.068067
# existing_emi_obligations         -0.001553      0.091145       0.080617
# collateral_value                  1.000000     -0.030340      -0.027940
# default_flag                     -0.030340      1.000000       0.868936
# days_past_due                    -0.027940      0.868936       1.000000
# recovery_amount                   0.018047      0.702852       0.603805
# payment_history_score             0.012825     -0.809830      -0.878369
# bounce_count                     -0.025805      0.836439       0.724691
# emi_to_income_ratio               0.172630      0.075061       0.065616
# loan_utilization                 -0.003256     -0.002530      -0.002453
# approval_percentage               0.013486      0.007345       0.004817
# high_risk_flag                         NaN           NaN            NaN
#
#                           recovery_amount  payment_history_score  \
# age                              0.000712              -0.003897
# years_with_employer              0.000150               0.001992
# annual_income                    0.034588               0.128335
# monthly_income                   0.013944               0.043210
# pincode                         -0.000986               0.000054
# loan_amount                      0.062012               0.033027
# sanctioned_amount                0.081699               0.038536
# disbursed_amount                 0.081609               0.038556
# interest_rate                    0.014140               0.004874
# tenure_months                   -0.036016               0.166725
# emi_amount                       0.095932              -0.100818
# processing_fee                   0.068141               0.033181
# credit_score                    -0.078342               0.082979
# debt_to_income_ratio             0.093019              -0.433295
# existing_loans_count             0.043260              -0.210739
# existing_emi_obligations         0.050471              -0.252647
# collateral_value                 0.018047               0.012825
# default_flag                     0.702852              -0.809830
# days_past_due                    0.603805              -0.878369
# recovery_amount                  1.000000              -0.554915
# payment_history_score           -0.554915               1.000000
# bounce_count                     0.578174              -0.673143
# emi_to_income_ratio              0.096582              -0.268151
# loan_utilization                -0.002544               0.000273
# approval_percentage              0.010895              -0.010246
# high_risk_flag                        NaN                    NaN
#
#                           bounce_count  emi_to_income_ratio  loan_utilization  \
# age                           0.003264             0.004794          0.002018
# years_with_employer          -0.000204            -0.002393         -0.000984
# annual_income                -0.063416            -0.000482         -0.004073
# monthly_income               -0.020279            -0.048951         -0.001256
# pincode                       0.003293            -0.002324         -0.001478
# loan_amount                  -0.030895             0.219568         -0.000804
# sanctioned_amount            -0.036706             0.274596         -0.002839
# disbursed_amount             -0.036744             0.274712          0.008980
# interest_rate                 0.016194            -0.077625          0.011502
# tenure_months                -0.035220            -0.637803          0.002388
# emi_amount                   -0.003413             0.688895          0.002520
# processing_fee               -0.032106             0.236455         -0.005085
# credit_score                 -0.089160            -0.000266          0.001537
# debt_to_income_ratio          0.128573             0.677927          0.003828
# existing_loans_count          0.062298            -0.001808         -0.003785
# existing_emi_obligations      0.075330            -0.000470         -0.002686
# collateral_value             -0.025805             0.172630         -0.003256
# default_flag                  0.836439             0.075061         -0.002530
# days_past_due                 0.724691             0.065616         -0.002453
# recovery_amount               0.578174             0.096582         -0.002544
# payment_history_score        -0.673143            -0.268151          0.000273
# bounce_count                  1.000000             0.060584         -0.001971
# emi_to_income_ratio           0.060584             1.000000          0.008122
# loan_utilization             -0.001971             0.008122          1.000000
# approval_percentage           0.004819             0.029270         -0.003043
# high_risk_flag                     NaN                  NaN               NaN
#
#                           approval_percentage  high_risk_flag
# age                                 -0.003057             NaN
# years_with_employer                 -0.001987             NaN
# annual_income                       -0.003521             NaN
# monthly_income                      -0.000844             NaN
# pincode                              0.001237             NaN
# loan_amount                         -0.346360             NaN
# sanctioned_amount                    0.023866             NaN
# disbursed_amount                     0.023831             NaN
# interest_rate                       -0.002465             NaN
# tenure_months                       -0.000906             NaN
# emi_amount                           0.016879             NaN
# processing_fee                       0.020014             NaN
# credit_score                        -0.005812             NaN
# debt_to_income_ratio                 0.022047             NaN
# existing_loans_count                -0.001401             NaN
# existing_emi_obligations            -0.001217             NaN
# collateral_value                     0.013486             NaN
# default_flag                         0.007345             NaN
# days_past_due                        0.004817             NaN
# recovery_amount                      0.010895             NaN
# payment_history_score               -0.010246             NaN
# bounce_count                         0.004819             NaN
# emi_to_income_ratio                  0.029270             NaN
# loan_utilization                    -0.003043             NaN
# approval_percentage                  1.000000             NaN
# high_risk_flag                            NaN             NaN

# %%
plt.figure(figsize=(14,10))

sns.heatmap(
    corr,
    cmap="coolwarm",
    annot=False
)

plt.title("Correlation Matrix")

plt.show()

# %%
# High-Risk Customer Profile
high_risk = df[df["high_risk_flag"] == 1]

print("Total High Risk Customers :", len(high_risk))

high_risk[
    [
        "credit_score",
        "annual_income",
        "loan_amount",
        "debt_to_income_ratio"
    ]
].describe()
# Out:
# Total High Risk Customers : 0
#        credit_score  annual_income  loan_amount  debt_to_income_ratio
# count           0.0            0.0          0.0                   0.0
# mean            NaN            NaN          NaN                   NaN
# std             NaN            NaN          NaN                   NaN
# min             NaN            NaN          NaN                   NaN
# 25%             NaN            NaN          NaN                   NaN
# 50%             NaN            NaN          NaN                   NaN
# 75%             NaN            NaN          NaN                   NaN
# max             NaN            NaN          NaN                   NaN

# %%
#Executive Credit Risk KPIs


print(f"Overall Default Rate      : {df['default_flag'].mean()*100:.2f}%")

print(f"Average Credit Score      : {df['credit_score'].mean():.2f}")

print(f"High Risk Customers       : {df['high_risk_flag'].sum():,}")

print(f"Average DTI Ratio         : {df['debt_to_income_ratio'].mean():.2f}")

print(f"Average Loan Amount       : ₹{df['loan_amount'].mean():,.2f}")
