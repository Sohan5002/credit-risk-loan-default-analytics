# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("loans_raw.csv")

# %%
df.head()
# Out:
#     loan_id applicant_id    customer_name  gender date_of_birth  age  \
# 0  LN157322     AP257322  Sunil Mukherjee    Male    1998-10-02   28
# 1  LN200595     AP300595     Dinesh Naidu    Male    2003-04-13   23
# 2  LN152399     AP252399      Karan Naidu    Male    1990-02-11   36
# 3  LN192773     AP292773   Vihaan Rathore    Male    1979-11-04   47
# 4  LN133442     AP233442     Komal Pillai  Female    1974-11-06   52
#
#   marital_status            education             occupation  \
# 0        Married        Post Graduate  Retail Business Owner
# 1        Married        Post Graduate  Trading Company Owner
# 2       Divorced  Professional Degree                Manager
# 3        Married  Professional Degree          Bank Employee
# 4        Married        Post Graduate             Freelancer
#
#           employment_type  ... recovery_amount  loan_officer_id  \
# 0          Business Owner  ...         95223.0          OFF0073
# 1          Business Owner  ...             0.0          OFF0080
# 2                Salaried  ...             0.0          OFF0112
# 3                Salaried  ...             0.0          OFF0015
# 4  Self-Employed Business  ...             0.0          OFF0146
#
#    loan_officer_name  payment_history_score bounce_count risk_category  \
# 0    Vivaan Kulkarni                  446.0            5           Low
# 1        Aarav Patil                  900.0            1           Low
# 2         Usha Sinha                  836.0            1           Low
# 3         Aarav More                  868.0            0           Low
# 4        Sneha Bhatt                  882.0            0           Low
#
#    customer_segment is_fraud_suspected kyc_verified           channel
# 0       Mass Market                 No          Yes       Digital App
# 1       Mass Market                 No          Yes       Digital App
# 2     Mass Affluent                 No          Yes    Branch Walk-in
# 3           Premium                 No          Yes  Corporate Tie-up
# 4       Mass Market                 No          Yes      Tele-calling
#
# [5 rows x 53 columns]

# %%
df.shape
# Out:
# (120720, 53)

# %%
df.columns.tolist()
# Out:
# ['loan_id',
#  'applicant_id',
#  'customer_name',
#  'gender',
#  'date_of_birth',
#  'age',
#  'marital_status',
#  'education',
#  'occupation',
#  'employment_type',
#  'employer_name',
#  'years_with_employer',
#  'annual_income',
#  'monthly_income',
#  'city',
#  'state',
#  'pincode',
#  'branch_id',
#  'branch_name',
#  'region',
#  'loan_product',
#  'loan_purpose',
#  'loan_amount',
#  'sanctioned_amount',
#  'disbursed_amount',
#  'interest_rate',
#  'tenure_months',
#  'emi_amount',
#  'processing_fee',
#  'credit_score',
#  'debt_to_income_ratio',
#  'existing_loans_count',
#  'existing_emi_obligations',
#  'collateral_type',
#  'collateral_value',
#  'co_applicant_flag',
#  'application_date',
#  'approval_date',
#  'disbursal_date',
#  'loan_status',
#  'default_flag',
#  'days_past_due',
#  'npa_flag',
#  'recovery_amount',
#  'loan_officer_id',
#  'loan_officer_name',
#  'payment_history_score',
#  'bounce_count',
#  'risk_category',
#  'customer_segment',
#  'is_fraud_suspected',
#  'kyc_verified',
#  'channel']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120720 entries, 0 to 120719
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   120720 non-null  str
#  1   applicant_id              120720 non-null  str
#  2   customer_name             120720 non-null  str
#  3   gender                    120720 non-null  str
#  4   date_of_birth             120720 non-null  str
#  5   age                       120720 non-null  int64
#  6   marital_status            120720 non-null  str
#  7   education                 120720 non-null  str
#  8   occupation                120720 non-null  str
#  9   employment_type           120720 non-null  str
#  10  employer_name             116868 non-null  str
#  11  years_with_employer       116000 non-null  float64
#  12  annual_income             114809 non-null  float64
#  13  monthly_income            115354 non-null  float64
#  14  city                      120720 non-null  str
#  15  state                     120720 non-null  str
#  16  pincode                   120720 non-null  int64
#  17  branch_id                 120720 non-null  str
#  18  branch_name               120720 non-null  str
#  19  region                    120720 non-null  str
#  20  loan_product              120720 non-null  str
#  21  loan_purpose              120720 non-null  str
#  22  loan_amount               120720 non-null  float64
#  23  sanctioned_amount         120720 non-null  float64
#  24  disbursed_amount          120720 non-null  float64
#  25  interest_rate             120720 non-null  float64
#  26  tenure_months             120720 non-null  int64
#  27  emi_amount                120720 non-null  float64
#  28  processing_fee            120720 non-null  float64
#  29  credit_score              115646 non-null  float64
#  30  debt_to_income_ratio      120720 non-null  float64
#  31  existing_loans_count      120720 non-null  int64
#  32  existing_emi_obligations  120720 non-null  float64
#  33  collateral_type           48407 non-null   str
#  34  collateral_value          116624 non-null  float64
#  35  co_applicant_flag         115653 non-null  str
#  36  application_date          120720 non-null  str
#  37  approval_date             120720 non-null  str
#  38  disbursal_date            120720 non-null  str
#  39  loan_status               120720 non-null  str
#  40  default_flag              120720 non-null  int64
#  41  days_past_due             115500 non-null  float64
#  42  npa_flag                  120720 non-null  str
#  43  recovery_amount           115911 non-null  float64
#  44  loan_officer_id           120720 non-null  str
#  45  loan_officer_name         120720 non-null  str
#  46  payment_history_score     116122 non-null  float64
#  47  bounce_count              120720 non-null  int64
#  48  risk_category             120720 non-null  str
#  49  customer_segment          120720 non-null  str
#  50  is_fraud_suspected        120720 non-null  str
#  51  kyc_verified              120720 non-null  str
#  52  channel                   120720 non-null  str
# dtypes: float64(16), int64(6), str(31)
# memory usage: 48.8 MB

# %%
df[['date_of_birth',
    'application_date',
    'approval_date',
    'disbursal_date']].head()
# Out:
#   date_of_birth application_date approval_date disbursal_date
# 0    1998-10-02      21 Sep 2025    09/27/2025     01-10-2025
# 1    2003-04-13       26/01/2023   28 Jan 2023    30 Jan 2023
# 2    1990-02-11       23/07/2025    01-08-2025     04/08/2025
# 3    1979-11-04       2025-07-05    07/06/2025    09 Jul 2025
# 4    1974-11-06       09/14/2025    2025-09-23     26-09-2025

# %%
date_columns =[
    "date_of_birth",
    "application_date",
    "approval_date",
    "disbursal_date"]
for col in date_columns:
    df[col]=pd.to_datetime(df[col],format="mixed",dayfirst=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120720 entries, 0 to 120719
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loan_id                   120720 non-null  str
#  1   applicant_id              120720 non-null  str
#  2   customer_name             120720 non-null  str
#  3   gender                    120720 non-null  str
#  4   date_of_birth             120720 non-null  datetime64[us]
#  5   age                       120720 non-null  int64
#  6   marital_status            120720 non-null  str
#  7   education                 120720 non-null  str
#  8   occupation                120720 non-null  str
#  9   employment_type           120720 non-null  str
#  10  employer_name             116868 non-null  str
#  11  years_with_employer       116000 non-null  float64
#  12  annual_income             114809 non-null  float64
#  13  monthly_income            115354 non-null  float64
#  14  city                      120720 non-null  str
#  15  state                     120720 non-null  str
#  16  pincode                   120720 non-null  int64
#  17  branch_id                 120720 non-null  str
#  18  branch_name               120720 non-null  str
#  19  region                    120720 non-null  str
#  20  loan_product              120720 non-null  str
#  21  loan_purpose              120720 non-null  str
#  22  loan_amount               120720 non-null  float64
#  23  sanctioned_amount         120720 non-null  float64
#  24  disbursed_amount          120720 non-null  float64
#  25  interest_rate             120720 non-null  float64
#  26  tenure_months             120720 non-null  int64
#  27  emi_amount                120720 non-null  float64
#  28  processing_fee            120720 non-null  float64
#  29  credit_score              115646 non-null  float64
#  30  debt_to_income_ratio      120720 non-null  float64
#  31  existing_loans_count      120720 non-null  int64
#  32  existing_emi_obligations  120720 non-null  float64
#  33  collateral_type           48407 non-null   str
#  34  collateral_value          116624 non-null  float64
#  35  co_applicant_flag         115653 non-null  str
#  36  application_date          120720 non-null  datetime64[us]
#  37  approval_date             120720 non-null  datetime64[us]
#  38  disbursal_date            120720 non-null  datetime64[us]
#  39  loan_status               120720 non-null  str
#  40  default_flag              120720 non-null  int64
#  41  days_past_due             115500 non-null  float64
#  42  npa_flag                  120720 non-null  str
#  43  recovery_amount           115911 non-null  float64
#  44  loan_officer_id           120720 non-null  str
#  45  loan_officer_name         120720 non-null  str
#  46  payment_history_score     116122 non-null  float64
#  47  bounce_count              120720 non-null  int64
#  48  risk_category             120720 non-null  str
#  49  customer_segment          120720 non-null  str
#  50  is_fraud_suspected        120720 non-null  str
#  51  kyc_verified              120720 non-null  str
#  52  channel                   120720 non-null  str
# dtypes: datetime64[us](4), float64(16), int64(6), str(27)
# memory usage: 48.8 MB

# %%
missing = df.isnull().sum()

missing = missing[missing > 0]

missing.sort_values(ascending=False)
print(missing)
# Out:
# employer_name             3852
# years_with_employer       4720
# annual_income             5911
# monthly_income            5366
# credit_score              5074
# collateral_type          72313
# collateral_value          4096
# co_applicant_flag         5067
# days_past_due             5220
# recovery_amount           4809
# payment_history_score     4598
# dtype: int64

# %%
df.groupby("loan_product")["collateral_type"].apply(lambda x: x.isnull().sum())
# Out:
# loan_product
# Auto Loan            0
# Business Loan    24106
# Gold Loan            0
# Personal Loan    48207
# Name: collateral_type, dtype: int64

# %%
df[['annual_income', 'monthly_income']].head(10)
# Out:
#    annual_income  monthly_income
# 0            NaN         43900.0
# 1       685200.0         57100.0
# 2       816000.0             NaN
# 3      2404800.0        200400.0
# 4       633600.0         52800.0
# 5       998400.0         83200.0
# 6      1068000.0         89000.0
# 7       536400.0         44700.0
# 8       415200.0         34600.0
# 9       456000.0         38000.0

# %%
df[['annual_income', 'monthly_income']].isnull().sum()
# Out:
# annual_income     5911
# monthly_income    5366
# dtype: int64

# %%
(df["annual_income"]/12).round(0).head(10)
# Out:
# 0         NaN
# 1     57100.0
# 2     68000.0
# 3    200400.0
# 4     52800.0
# 5     83200.0
# 6     89000.0
# 7     44700.0
# 8     34600.0
# 9     38000.0
# Name: annual_income, dtype: float64

# %%
df[['annual_income', 'monthly_income']].head(10)
# Out:
#    annual_income  monthly_income
# 0            NaN         43900.0
# 1       685200.0         57100.0
# 2       816000.0             NaN
# 3      2404800.0        200400.0
# 4       633600.0         52800.0
# 5       998400.0         83200.0
# 6      1068000.0         89000.0
# 7       536400.0         44700.0
# 8       415200.0         34600.0
# 9       456000.0         38000.0

# %%
df["monthly_income"].head(10)
# Out:
# 0     43900.0
# 1     57100.0
# 2         NaN
# 3    200400.0
# 4     52800.0
# 5     83200.0
# 6     89000.0
# 7     44700.0
# 8     34600.0
# 9     38000.0
# Name: monthly_income, dtype: float64

# %%
# Fill Annual Income
df["annual_income"] = df["annual_income"].fillna(df["monthly_income"] * 12)

# Fill Monthly Income
df["monthly_income"] = df["monthly_income"].fillna(df["annual_income"] / 12)

# %%
df[["annual_income", "monthly_income"]].isnull().sum()
# Out:
# annual_income     246
# monthly_income    246
# dtype: int64

# %%
df[df["annual_income"].isnull() & df["monthly_income"].isnull()][["annual_income","monthly_income"]].head(10)
# Out:
#       annual_income  monthly_income
# 86              NaN             NaN
# 658             NaN             NaN
# 665             NaN             NaN
# 2251            NaN             NaN
# 3891            NaN             NaN
# 4471            NaN             NaN
# 4754            NaN             NaN
# 5226            NaN             NaN
# 5478            NaN             NaN
# 5501            NaN             NaN

# %%
df[df["annual_income"].isnull()].groupby("loan_product").size()
# Out:
# loan_product
# Auto Loan         61
# Business Loan     42
# Gold Loan         38
# Personal Loan    105
# dtype: int64

# %%
df[df["annual_income"].isnull()].isnull().sum()
# Out:
# loan_id                       0
# applicant_id                  0
# customer_name                 0
# gender                        0
# date_of_birth                 0
# age                           0
# marital_status                0
# education                     0
# occupation                    0
# employment_type               0
# employer_name                11
# years_with_employer          11
# annual_income               246
# monthly_income              246
# city                          0
# state                         0
# pincode                       0
# branch_id                     0
# branch_name                   0
# region                        0
# loan_product                  0
# loan_purpose                  0
# loan_amount                   0
# sanctioned_amount             0
# disbursed_amount              0
# interest_rate                 0
# tenure_months                 0
# emi_amount                    0
# processing_fee                0
# credit_score                  5
# debt_to_income_ratio          0
# existing_loans_count          0
# existing_emi_obligations      0
# collateral_type             147
# collateral_value              6
# co_applicant_flag             6
# application_date              0
# approval_date                 0
# disbursal_date                0
# loan_status                   0
# default_flag                  0
# days_past_due                14
# npa_flag                      0
# recovery_amount              14
# loan_officer_id               0
# loan_officer_name             0
# payment_history_score        10
# bounce_count                  0
# risk_category                 0
# customer_segment              0
# is_fraud_suspected            0
# kyc_verified                  0
# channel                       0
# dtype: int64

# %%
df["annual_income"] = df["annual_income"].fillna(
    df.groupby("loan_product")["annual_income"].transform("median")
)

df["monthly_income"] = df["monthly_income"].fillna(
    df.groupby("loan_product")["monthly_income"].transform("median")
)

# %%
# ================================
# Credit Score Validation & Cleaning
# ================================

# %%
# Step 2: Credit Score Validation & Cleaning

#Objective:Validate the credit score column, identify missing values, check the valid range, and decide the best cleaning strategy based on business logic.

# %%
#Missing Values
print("Missing Values:", df["credit_score"].isnull().sum())
# Out:
# Missing Values: 5074

# %%
# Minimum and Maximum Credit Score
print("Minimum Credit Score:", df["credit_score"].min())
print("Maximum Credit Score:", df["credit_score"].max())
# Out:
# Minimum Credit Score: 300.0
# Maximum Credit Score: 900.0

# %%
df["credit_score"].describe()
# Out:
# count    115646.000000
# mean        679.826946
# std          89.202642
# min         300.000000
# 25%         620.000000
# 50%         680.000000
# 75%         740.000000
# max         900.000000
# Name: credit_score, dtype: float64

# %%
# median are less effect by outliers
df["credit_score"].fillna(
    df["credit_score"].median()
)
# Out:
# 0         680.0
# 1         697.0
# 2         633.0
# 3         465.0
# 4         699.0
#           ...
# 120715    645.0
# 120716    672.0
# 120717    658.0
# 120718    667.0
# 120719    704.0
# Name: credit_score, Length: 120720, dtype: float64

# %%
df["credit_score"] = df["credit_score"].fillna(
    df["credit_score"].median()
)

# %%
df["credit_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["credit_score"] = df["credit_score"].fillna(
    df["credit_score"].median()
)

df["credit_score"].isnull().sum()
# Out:
# np.int64(0)

# %%
### Credit Score Cleaning

#**Observation:**
#- Missing Values: 5074
#- Valid Range: 300 900
#- Median Credit Score: 680

#**Cleaning Strategy:**
#Filled missing values using the median because the median is less affected by outliers than the mean.

#**Result:**
#Missing values reduced from 5074 to 0.

# %%
df[df["employer_name"].isnull()][
    ["employment_type", "employer_name", "years_with_employer"]
].head(20)
# Out:
#                 employment_type employer_name  years_with_employer
# 95                     Salaried           NaN                  8.6
# 123                    Salaried           NaN                  NaN
# 169                    Salaried           NaN                  5.7
# 196                    Salaried           NaN                  6.0
# 197      Self-Employed Business           NaN                  7.6
# 230                    Salaried           NaN                  NaN
# 237                    Salaried           NaN                  7.4
# 253      Self-Employed Business           NaN                  8.1
# 257      Self-Employed Business           NaN                  7.3
# 300                    Salaried           NaN                  3.9
# 301                    Salaried           NaN                  4.2
# 315                    Salaried           NaN                  1.8
# 381      Self-Employed Business           NaN                  2.1
# 413                    Salaried           NaN                  5.3
# 418                    Salaried           NaN                  2.4
# 455                    Salaried           NaN                  4.7
# 537  Self-Employed Professional           NaN                  7.8
# 538                    Salaried           NaN                  1.6
# 556                    Salaried           NaN                  NaN
# 557  Self-Employed Professional           NaN                  2.0

# %%
df["employer_name"] = df["employer_name"].fillna("Unknown")

# %%
df["years_with_employer"].isnull().sum()
# Out:
# np.int64(4720)

# %%
df[df["years_with_employer"].isnull()].groupby("employment_type").size()
# Out:
# employment_type
# Business Owner                 428
# Salaried                      2675
# Self-Employed Business         914
# Self-Employed Professional     703
# dtype: int64

# %%
df["years_with_employer"] = df["years_with_employer"].fillna(
    df.groupby("employment_type")["years_with_employer"].transform("median")
)

# %%
df["years_with_employer"] = df["years_with_employer"].fillna(
    df.groupby("employment_type")["years_with_employer"].transform("median")
)

df["years_with_employer"].isnull().sum()
# Out:
# np.int64(0)

# %%
df[df["employer_name"].isnull()].groupby("employment_type").size()
# Out:
# Series([], dtype: int64)

# %%
df["co_applicant_flag"].value_counts(dropna=False)
# Out:
# co_applicant_flag
# No     83333
# Yes    32320
# NaN     5067
# Name: count, dtype: int64

# %%
#Check Missing Values by Loan Status
df[df["co_applicant_flag"].isnull()]["loan_status"].value_counts()
# Out:
# loan_status
# Active         3537
# Closed         1250
# Default         262
# Written-Off      18
# Name: count, dtype: int64

# %%
#Check Missing Values by Employment Type
df[df["co_applicant_flag"].isnull()]["employment_type"].value_counts()
# Out:
# employment_type
# Salaried                      2786
# Self-Employed Business        1008
# Self-Employed Professional     753
# Business Owner                 520
# Name: count, dtype: int64

# %%
df[df["co_applicant_flag"].isnull()]["loan_product"].value_counts()
# Out:
# loan_product
# Personal Loan    2057
# Auto Loan        1326
# Business Loan     967
# Gold Loan         717
# Name: count, dtype: int64

# %%
# Overall distribution
df["co_applicant_flag"].value_counts(normalize=True, dropna=False) * 100
# Out:
# co_applicant_flag
# No     69.029987
# Yes    26.772697
# NaN     4.197316
# Name: proportion, dtype: float64

# %%
# Loan status vs Co-applicant
pd.crosstab(
    df["loan_status"],
    df["co_applicant_flag"],
    normalize="index"
) * 100
# Out:
# co_applicant_flag         No        Yes
# loan_status
# Active             72.140672  27.859328
# Closed             71.801285  28.198715
# Default            71.914069  28.085931
# Written-Off        74.458874  25.541126

# %%
df["co_applicant_flag"] = df["co_applicant_flag"].fillna("No")

# %%
df["co_applicant_flag"].isnull().sum()
# Out:
# np.int64(0)

# %%
#Collateral Type
df["collateral_type"].isnull().sum()
# Out:
# np.int64(72313)

# %%
df["collateral_type"].value_counts(dropna=False)
# Out:
# collateral_type
# NaN                      72313
# Vehicle Hypothecation    30269
# Gold Ornaments           18138
# Name: count, dtype: int64

# %%
df[df["collateral_type"].isnull()]["loan_product"].value_counts()
# Out:
# loan_product
# Personal Loan    48207
# Business Loan    24106
# Name: count, dtype: int64

# %%
df[df["collateral_type"].isnull()]["loan_status"].value_counts()
# Out:
# loan_status
# Active         52388
# Closed         15817
# Default         3794
# Written-Off      314
# Name: count, dtype: int64

# %%
df["collateral_type"] = df["collateral_type"].fillna("No Collateral")

# %%
df["collateral_type"] = df["collateral_type"].fillna("No Collateral")

# %%
df["collateral_type"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["collateral_type"].value_counts()
# Out:
# collateral_type
# No Collateral            72313
# Vehicle Hypothecation    30269
# Gold Ornaments           18138
# Name: count, dtype: int64
